# %% [markdown]
# # Linear Regression : Single-variable

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     107       force_remount=force_remount,
#     108       timeout_ms=timeout_ms,
# --> 109       ephemeral=True)
#     110
#     111
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral)
#     122   if ephemeral:
#     123     _message.blocking_request(
# --> 124         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     125
#     126   mountpoint = _os.path.expanduser(mountpoint)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     173   request_id = send_request(
#     174       request_type, request, parent=parent, expect_reply=True)
# --> 175   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: Error: credential propagation was unsuccessful

# %%
x_data = np.array([1,2,3,4,5]).reshape(5,1)
t_data = np.array([2,3,4,5,6]).reshape(5,1)

print("X_data = ", x_data.shape, ", t_data.shape = ", t_data.shape)
print(x_data)
# Out:
# X_data =  (5, 1) , t_data.shape =  (5, 1)
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]

# %%
W = np.random.rand(1, 1)
b = np.random.rand(1)

print('W = ', W, ", W.shape = ", W.shape, ", b = ", b, ", b.shape = ", b.shape)
# Out:
# W =  [[0.29237656]] , W.shape =  (1, 1) , b =  [0.77018661] , b.shape =  (1,)

# %%
def loss_func(x, t):
  y = np.dot(x, W) + b

  return (np.sum((t-y)**2)) / len(x)

# %%
def numerical_derivative(f, x):
  delta_x = 1e-4
  grad = np.zeros_like(x)

  it = np.nditer(x, flags = ['multi_index'], op_flags = ['readwrite'])

  while not it.finished:
    idx = it.multi_index
    tmp_val = x[idx]
    x[idx] = float(tmp_val) + delta_x
    fx1 = f(x)

    x[idx] = tmp_val - delta_x
    fx2 = f(x)
    grad[idx] = (fx1 - fx2) / (2 * delta_x)

    x[idx] = tmp_val
    it.iternext()
  return grad

# %%
def error_val(x, t):
  y = np.dot(x, W) + b
  return (np.sum((t-y)**2)) / len(x)

def predict(x):
  y = np.dot(x, W) + b
  return y

# %%
learning_rate = 1e-3
f = lambda x : loss_func(x_data, t_data)

print('Initial error value = ', error_val(x_data, t_data))
print('Initial W = ', W, ', b = ', b)

for step in range(10001):
  W -= learning_rate * numerical_derivative(f, W)
  b -= learning_rate * numerical_derivative(f, b)

  if (step % 400 == 0):
    print("step = ", step, "error value = ", error_val(x_data, t_data), "W = ", W, ", b = ", b)
# Out:
# Initial error value =  6.536582545643272
# Initial W =  [[0.29237656]] , b =  [0.77018661]
# step =  0 error value =  6.231381737541334 W =  [[0.30932315]] , b =  [0.7747903]
# step =  400 error value =  0.00017445765114259087 W =  [[1.00852549]] , b =  [0.96903004]
# step =  800 error value =  0.00013303126256654336 W =  [[1.00748832]] , b =  [0.97296542]
# step =  1200 error value =  0.00010145782377719433 W =  [[1.00653959]] , b =  [0.97639057]
# step =  1600 error value =  7.737797710856347e-05 W =  [[1.00571106]] , b =  [0.97938177]
# step =  2000 error value =  5.901320488167531e-05 W =  [[1.00498749]] , b =  [0.981994]
# step =  2400 error value =  4.500709995972512e-05 W =  [[1.0043556]] , b =  [0.98427527]
# step =  2800 error value =  3.432518282723799e-05 W =  [[1.00380377]] , b =  [0.98626752]
# step =  3200 error value =  2.6178495774618796e-05 W =  [[1.00332185]] , b =  [0.98800735]
# step =  3600 error value =  1.9965331123532645e-05 W =  [[1.00290099]] , b =  [0.98952676]
# step =  4000 error value =  1.522678958730539e-05 W =  [[1.00253345]] , b =  [0.99085367]
# step =  4400 error value =  1.1612886342901997e-05 W =  [[1.00221247]] , b =  [0.99201247]
# step =  4800 error value =  8.85670143663586e-06 W =  [[1.00193216]] , b =  [0.99302445]
# step =  5200 error value =  6.754665293493773e-06 W =  [[1.00168737]] , b =  [0.99390821]
# step =  5600 error value =  5.151523233966604e-06 W =  [[1.00147359]] , b =  [0.99468001]
# step =  6000 error value =  3.928868489702085e-06 W =  [[1.00128689]] , b =  [0.99535403]
# step =  6400 error value =  2.9963967759276075e-06 W =  [[1.00112385]] , b =  [0.99594265]
# step =  6800 error value =  2.2852364904362073e-06 W =  [[1.00098146]] , b =  [0.9964567]
# step =  7200 error value =  1.7428619130736286e-06 W =  [[1.00085712]] , b =  [0.99690562]
# step =  7600 error value =  1.329213698781104e-06 W =  [[1.00074852]] , b =  [0.99729766]
# step =  8000 error value =  1.0137401269564637e-06 W =  [[1.00065369]] , b =  [0.99764003]
# step =  8400 error value =  7.731405762250325e-07 W =  [[1.00057087]] , b =  [0.99793903]
# step =  8800 error value =  5.89644559499726e-07 W =  [[1.00049854]] , b =  [0.99820014]
# step =  9200 error value =  4.4969921025862616e-07 W =  [[1.00043538]] , b =  [0.99842818]
# step =  9600 error value =  3.429682788542252e-07 W =  [[1.00038022]] , b =  [0.99862732]
# step =  10000 error value =  2.615687055182613e-07 W =  [[1.00033205]] , b =  [0.99880123]

# %%
predict(43)
# Out:
# array([[44.01307929]])

# %% [markdown]
# >> ### 실습. 위 데이터를 예측을 잘 할 수 있도록, learning_rate 및 step을 수정해 볼 것.

# %% [markdown]
# # Linear Regression : Multi-variable

# %%
import numpy as np

# %%
cd /content/drive/MyDrive/Colab Notebooks/2021_2학기_데이터분석과머신러닝/LinearRegression_LogisticRegression
# Out:
# /content/drive/MyDrive/Colab Notebooks/2021_2학기_데이터분석과머신러닝/LinearRegression_LogisticRegression

# %%
# !dir
# Out:
# data-01-test-score.csv		    RFMiD_Test_SET.csv
# Linear_Regression.ipynb		    RFMiD_Train_SET.csv
# Logistic_Regression_실습모드.ipynb

# %%
loaded_data = np.loadtxt('data-01-test-score.csv', delimiter=',', dtype=np.float32)

x_data = loaded_data[:, 0:-1]
t_data = loaded_data[:, [-1]]

print("x_data.ndim = ", x_data.ndim, ", x_data.shape = ", x_data.shape)
print("t_data.ndim = ", t_data.ndim, ", t_data.shape = ", t_data.shape)
# Out:
# x_data.ndim =  2 , x_data.shape =  (25, 3)
# t_data.ndim =  2 , t_data.shape =  (25, 1)

# %%
W = np.random.rand(3, 1)
b = np.random.rand(1)

print('W = ', W, ", W.shape = ", W.shape, ", b = ", b, ", b.shape = ", b.shape)
# Out:
# W =  [[0.71020852]
#  [0.2110497 ]
#  [0.62697213]] , W.shape =  (3, 1) , b =  [0.10349584] , b.shape =  (1,)

# %%
def loss_func(x, t):
  y = np.dot(x, W) + b

  return (np.sum((t-y)**2)) / len(x)

# %%
def numerical_derivative(f, x):
  delta_x = 1e-4
  grad = np.zeros_like(x)

  it = np.nditer(x, flags = ['multi_index'], op_flags = ['readwrite'])

  while not it.finished:
    idx = it.multi_index
    tmp_val = x[idx]
    x[idx] = float(tmp_val) + delta_x
    fx1 = f(x)

    x[idx] = tmp_val - delta_x
    fx2 = f(x)
    grad[idx] = (fx1 - fx2) / (2 * delta_x)

    x[idx] = tmp_val
    it.iternext()
  return grad

# %%
def error_val(x, t):
  y = np.dot(x, W) + b
  return (np.sum((t-y)**2)) / len(x)

def predict(x):
  y = np.dot(x, W) + b
  return y

# %%
learning_rate = 1e-7
f = lambda x : loss_func(x_data, t_data)

print('Initial error value = ', error_val(x_data, t_data))
print('Initial W = ', W, ', b = ', b)

for step in range(100001):
  W -= learning_rate * numerical_derivative(f, W)
  b -= learning_rate * numerical_derivative(f, b)

  if (step % 400 == 0):
    print("step = ", step, "error value = ", error_val(x_data, t_data), "W = ", W, ", b = ", b)

# %%
test_data = np.array([100, 98, 81])
predict(test_data)
# Out:
# array([185.5887024])

# %% [markdown]
# >> ### 실습. 위 코드에서 학습률이 1e-5일 때, 10,000 step을 한 경우와, 1e-3일 때, 10,000과 50,000 step을 진행한 경우의 결과를 확인하라.

# %%
learning_rate = 1e-7
for step in range(100001):
array([185.5887024])
