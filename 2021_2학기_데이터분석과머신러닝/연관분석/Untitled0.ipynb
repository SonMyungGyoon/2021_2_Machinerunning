# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
dataset = [['삼겹살', '상추'],
           ['삼겹살', '상추', '사이다'],
           ['삼겹살', '깻잎'],
           ['닭고기', '샤워 타올'],
           ['닭고기', '콜라', '사이다']]

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
print(df)
# Out:
#       깻잎    닭고기    사이다    삼겹살     상추  샤워 타올     콜라
# 0  False  False  False   True   True  False  False
# 1  False  False   True   True   True  False  False
# 2   True  False  False   True  False  False  False
# 3  False   True  False  False  False   True  False
# 4  False   True   True  False  False  False   True

# %%
frequent_itemsets = apriori(df, min_support=0.1, use_colnames=True)
print(frequent_itemsets)
# Out:
#     support        itemsets
# 0       0.2            (깻잎)
# 1       0.4           (닭고기)
# 2       0.4           (사이다)
# 3       0.6           (삼겹살)
# 4       0.4            (상추)
# 5       0.2         (샤워 타올)
# 6       0.2            (콜라)
# 7       0.2       (깻잎, 삼겹살)
# 8       0.2      (닭고기, 사이다)
# 9       0.2    (닭고기, 샤워 타올)
# 10      0.2       (콜라, 닭고기)
# 11      0.2      (삼겹살, 사이다)
# 12      0.2       (상추, 사이다)
# 13      0.2       (콜라, 사이다)
# 14      0.4       (상추, 삼겹살)
# 15      0.2  (콜라, 닭고기, 사이다)
# 16      0.2  (상추, 삼겹살, 사이다)

# %%
association_rules(frequent_itemsets, metric='lift', min_threshold=1)
# Out:
#    antecedents consequents  antecedent support  ...      lift  leverage  conviction
# 0         (깻잎)       (삼겹살)                 0.2  ...  1.666667      0.08         inf
# 1        (삼겹살)        (깻잎)                 0.6  ...  1.666667      0.08         1.2
# 2        (닭고기)       (사이다)                 0.4  ...  1.250000      0.04         1.2
# 3        (사이다)       (닭고기)                 0.4  ...  1.250000      0.04         1.2
# 4        (닭고기)     (샤워 타올)                 0.4  ...  2.500000      0.12         1.6
# 5      (샤워 타올)       (닭고기)                 0.2  ...  2.500000      0.12         inf
# 6         (콜라)       (닭고기)                 0.2  ...  2.500000      0.12         inf
# 7        (닭고기)        (콜라)                 0.4  ...  2.500000      0.12         1.6
# 8         (상추)       (사이다)                 0.4  ...  1.250000      0.04         1.2
# 9        (사이다)        (상추)                 0.4  ...  1.250000      0.04         1.2
# 10        (콜라)       (사이다)                 0.2  ...  2.500000      0.12         inf
# 11       (사이다)        (콜라)                 0.4  ...  2.500000      0.12         1.6
# 12        (상추)       (삼겹살)                 0.4  ...  1.666667      0.16         inf
# 13       (삼겹살)        (상추)                 0.6  ...  1.666667      0.16         1.8
# 14   (콜라, 닭고기)       (사이다)                 0.2  ...  2.500000      0.12         inf
# 15   (콜라, 사이다)       (닭고기)                 0.2  ...  2.500000      0.12         inf
# 16  (닭고기, 사이다)        (콜라)                 0.2  ...  5.000000      0.16         inf
# 17        (콜라)  (닭고기, 사이다)                 0.2  ...  5.000000      0.16         inf
# 18       (닭고기)   (콜라, 사이다)                 0.4  ...  2.500000      0.12         1.6
# 19       (사이다)   (콜라, 닭고기)                 0.4  ...  2.500000      0.12         1.6
# 20   (상추, 삼겹살)       (사이다)                 0.4  ...  1.250000      0.04         1.2
# 21   (상추, 사이다)       (삼겹살)                 0.2  ...  1.666667      0.08         inf
# 22  (삼겹살, 사이다)        (상추)                 0.2  ...  2.500000      0.12         inf
# 23        (상추)  (삼겹살, 사이다)                 0.4  ...  2.500000      0.12         1.6
# 24       (삼겹살)   (상추, 사이다)                 0.6  ...  1.666667      0.08         1.2
# 25       (사이다)   (상추, 삼겹살)                 0.4  ...  1.250000      0.04         1.2
#
# [26 rows x 9 columns]

# %%
frequent_itemsets = apriori(df, min_support=0.3, use_colnames=True)
print(frequent_itemsets)
# Out:
#    support   itemsets
# 0      0.4      (닭고기)
# 1      0.4      (사이다)
# 2      0.6      (삼겹살)
# 3      0.4       (상추)
# 4      0.4  (상추, 삼겹살)

# %%
association_rules(frequent_itemsets, metric='lift', min_threshold=1)
# Out:
#   antecedents consequents  antecedent support  ...      lift  leverage  conviction
# 0        (상추)       (삼겹살)                 0.4  ...  1.666667      0.16         inf
# 1       (삼겹살)        (상추)                 0.6  ...  1.666667      0.16         1.8
#
# [2 rows x 9 columns]
